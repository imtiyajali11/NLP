# %%
import cv2

print("Imported successfully")

cap = cv2.VideoCapture(1)

print("Camera object created")

# %% [markdown]
# # OCR - Optical Character Recognition

# %%
import cv2

print("Imported successfully")
# Out:
# Imported successfully

# %%
# !pip install easyocr
print("Imported successfully")
# Out:
# Imported successfully

# %%
import easyocr
reader = easyocr.Reader(['en'],gpu= True)
text = reader.readtext('Documents/ITVEDANT/AI/images_with_text.png', detail=0)
# Out:
# [ WARN:0@143.759] global loadsave.cpp:278 findDecoder imread_('Documents/ITVEDANT/AI/images_with_text.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import easyocr
#       2 reader = easyocr.Reader(['en'],gpu= True)
# ----> 3 text = reader.readtext('Documents/ITVEDANT/AI/images_with_text.png', detail=0)
#       4
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/easyocr/easyocr.py:454, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     440 def readtext(self, image, decoder = 'greedy', beamWidth= 5, batch_size = 1,\
#     441              workers = 0, allowlist = None, blocklist = None, detail = 1,\
#     442              rotation_info = None, paragraph = False, min_size = 20,\
#    (...)    448              threshold = 0.2, bbox_min_score = 0.2, bbox_min_size = 3, max_candidates = 0,
#     449              output_format='standard'):
#     450     '''
#     451     Parameters:
#     452     image: file path or numpy-array or a byte stream object
#     453     '''
# --> 454     img, img_cv_grey = reformat_input(image)
#     456     horizontal_list, free_list = self.detect(img,
#     457                                              min_size = min_size, text_threshold = text_threshold,\
#     458                                              low_text = low_text, link_threshold = link_threshold,\
#    (...)    464                                              bbox_min_size = bbox_min_size, max_candidates = max_candidates
#     465                                              )
#     466     # get the 1st result from hor & free list as self.detect returns a list of depth 3
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/easyocr/utils.py:741, in reformat_input(image)
#     739         img_cv_grey = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
#     740         image = os.path.expanduser(image)
# --> 741     img = loadImage(image)  # can accept URL
#     742 elif type(image) == bytes:
#     743     nparr = np.frombuffer(image, np.uint8)
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/easyocr/imgproc.py:12, in loadImage(img_file)
#      11 def loadImage(img_file):
# ---> 12     img = io.imread(img_file)           # RGB order
#      13     if img.shape[0] == 2: img = img[0]
#      14     if len(img.shape) == 2 : img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/skimage/_shared/utils.py:386, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     382     elif self.new_name is not None:
#     383         # Assign old value to new one
#     384         kwargs[self.new_name] = deprecated_value
# --> 386 return func(*args, **kwargs)
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/skimage/io/_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
#      79         plugin = 'tifffile'
#      81 with file_or_url_context(fname) as fname, _hide_plugin_deprecation_warnings():
# ---> 82     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      84 if not hasattr(img, 'ndim'):
#      85     return img
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/skimage/_shared/utils.py:690, in deprecate_func.__call__.<locals>.wrapped(*args, **kwargs)
#     684 stacklevel = (
#     685     self.stacklevel
#     686     if self.stacklevel is not None
#     687     else _warning_stacklevel(func)
#     688 )
#     689 warnings.warn(message, category=FutureWarning, stacklevel=stacklevel)
# --> 690 return func(*args, **kwargs)
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/skimage/io/manage_plugins.py:254, in call_plugin(kind, *args, **kwargs)
#     251     except IndexError:
#     252         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 254 return func(*args, **kwargs)
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/skimage/io/_plugins/imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/imageio/v3.py:53, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      50 if index is not None:
#      51     call_kwargs["index"] = index
# ---> 53 with imopen(uri, "r", **plugin_kwargs) as img_file:
#      54     return np.asarray(img_file.read(**call_kwargs))
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/imageio/core/imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/imageio/core/request.py:250, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     247     raise ValueError(f"Invalid Request.Mode: {mode}")
#     249 # Parse what was given
# --> 250 self._parse_uri(uri)
#     252 # Set extension
#     253 if extension is not None:
#
# File ~/Documents/ITVEDANT/Python/.conda/lib/python3.12/site-packages/imageio/core/request.py:410, in Request._parse_uri(self, uri)
#     407 if is_read_request:
#     408     # Reading: check that the file exists (but is allowed a dir)
#     409     if not os.path.exists(fn):
# --> 410         raise FileNotFoundError("No such file: '%s'" % fn)
#     411 else:
#     412     # Writing: check that the directory to write to does exist
#     413     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: '/Users/alismac/Documents/ITVEDANT/AI/Documents/ITVEDANT/AI/images_with_text.png'
